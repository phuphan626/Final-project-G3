# %%
# Import Dependencies
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.preprocessing import LabelEncoder,MinMaxScaler
from sklearn.linear_model import LinearRegression

# %%
# Read in the file
file_path=pd.read_csv('consolidated_coin_data.csv')

# %%
# Convert to DataFrame
coin_df=pd.DataFrame(file_path)

# %%
# Display the DataFrame
coin_df
# Out:
#          Currency          Date  Open  High   Low Close      Volume  \
# 0           tezos  Dec 04, 2019  1.29  1.32  1.25  1.25  46,048,752
# 1           tezos  Dec 03, 2019  1.24  1.32  1.21  1.29  41,462,224
# 2           tezos  Dec 02, 2019  1.25  1.26  1.20  1.24  27,574,097
# 3           tezos  Dec 01, 2019  1.33  1.34  1.25  1.25  24,127,567
# 4           tezos  Nov 30, 2019  1.31  1.37  1.31  1.33  28,706,667
# ...           ...           ...   ...   ...   ...   ...         ...
# 28939  bitcoin-sv  May 02, 2013  3.78  4.04  3.01  3.37           0
# 28940  bitcoin-sv  May 01, 2013  4.29  4.36  3.52  3.80           0
# 28941  bitcoin-sv  Apr 30, 2013  4.40  4.57  4.17  4.30           0
# 28942  bitcoin-sv  Apr 29, 2013  4.37  4.57  4.23  4.38           0
# 28943  bitcoin-sv  Apr 28, 2013  4.30  4.40  4.18  4.35           0
#
#         Market Cap
# 0      824,588,509
# 1      853,213,342
# 2      817,872,179
# 3      828,296,390
# 4      879,181,680
# ...            ...
# ...

# %%
# Convert the data from last 6 columns
column_list=['Open','High','Low','Close','Volume','Market Cap']
for x in column_list:
    coin_df[x] = coin_df[x].str.replace(',', '').astype(float)

# %%
# Double check the type for the DataFrame
coin_df.dtypes
# Out:
# Currency       object
# Date           object
# Open          float64
# High          float64
# Low           float64
# Close         float64
# Volume        float64
# Market Cap    float64
# dtype: object

# %%
# Add an Average-medium column for the DataFrame
coin_df['Average']=(coin_df['Open']+coin_df['High']+coin_df['Low']+coin_df['Close'])/4

# %%
# Display the newly updated DataFrame
coin_df
# Out:
#          Currency          Date  Open  High   Low  Close      Volume  \
# 0           tezos  Dec 04, 2019  1.29  1.32  1.25   1.25  46048752.0
# 1           tezos  Dec 03, 2019  1.24  1.32  1.21   1.29  41462224.0
# 2           tezos  Dec 02, 2019  1.25  1.26  1.20   1.24  27574097.0
# 3           tezos  Dec 01, 2019  1.33  1.34  1.25   1.25  24127567.0
# 4           tezos  Nov 30, 2019  1.31  1.37  1.31   1.33  28706667.0
# ...           ...           ...   ...   ...   ...    ...         ...
# 28939  bitcoin-sv  May 02, 2013  3.78  4.04  3.01   3.37         0.0
# 28940  bitcoin-sv  May 01, 2013  4.29  4.36  3.52   3.80         0.0
# 28941  bitcoin-sv  Apr 30, 2013  4.40  4.57  4.17   4.30         0.0
# 28942  bitcoin-sv  Apr 29, 2013  4.37  4.57  4.23   4.38         0.0
# 28943  bitcoin-sv  Apr 28, 2013  4.30  4.40  4.18   4.35         0.0
#
#         Market Cap  Average
# 0      824588509.0   1.2775
# 1      853213342.0   1.2650
# 2      817872179.0   1.2375
# ...

# %%
# Set the index to Currency column 
coin_df=coin_df.set_index('Currency')

# %%
# Filter out for just bitcoin
btc_df=coin_df.loc['bitcoin']

# %%
# Display the btc_df
btc_df
# Out:
#                   Date     Open     High      Low    Close        Volume  \
# Currency
# bitcoin   Dec 04, 2019  7320.13  7539.78  7170.92  7252.03  2.166424e+10
# bitcoin   Dec 03, 2019  7323.98  7418.86  7229.36  7320.15  1.479749e+10
# bitcoin   Dec 02, 2019  7424.04  7474.82  7233.40  7321.99  1.708204e+10
# bitcoin   Dec 01, 2019  7571.62  7571.62  7291.34  7424.29  1.872071e+10
# bitcoin   Nov 30, 2019  7764.06  7836.10  7515.85  7569.63  1.715819e+10
# ...                ...      ...      ...      ...      ...           ...
# bitcoin   May 02, 2013   116.38   125.60    92.28   105.21  0.000000e+00
# bitcoin   May 01, 2013   139.00   139.89   107.72   116.99  0.000000e+00
# bitcoin   Apr 30, 2013   144.00   146.93   134.05   139.00  0.000000e+00
# bitcoin   Apr 29, 2013   134.44   147.49   134.00   144.54  0.000000e+00
# bitcoin   Apr 28, 2013   135.30   135.98   132.10   134.21  0.000000e+00
#
#             Market Cap    Average
# Currency
# bitcoin   1.311431e+11  7320.7150
# ...

# %%
# Select the X and y for the machine
X=coin_df.drop([],axis=1)
y=coin_df['Average']

# %%
print(X.shape,y.shape)
# Out:
# (28944, 3) (28944,)

# %%
# Create a Linear Regression model
model = LinearRegression()

# %%
# Fit in the model
model.fit(X,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-a14836b5d2a5> in <module>
#       1 # Fit in the model
# ----> 2 model.fit(X,y)
#
# ~\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     504         n_jobs_ = self.n_jobs
#     505         X, y = self._validate_data(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 506                                    y_numeric=True, multi_output=True)
#     507
#     508         if sample_weight is not None:
#
# ~\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
#     433             out = X, y
#     434
#
# ...

# %%
print(model)
# Out:
# LinearRegression()

# %%
print('Weight coefficients: ', model.coef_)
print('y-axis intercept: ', model.intercept_)
# Out:
# Weight coefficients:  [ 2.50000000e-01  2.50000000e-01  2.50000000e-01  2.50000000e-01
#  -1.07577169e-17  8.27631537e-17]
# y-axis intercept:  -5.205420166021213e-07
